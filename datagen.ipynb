# %%
import gzip
import pandas as pd
import json
from tqdm import tqdm
from itertools import islice
import gc

# %%
def readCSV(path):
    f = gzip.open(path, 'rt')
    f.readline()
    for l in f:
        u,b,r = l.strip().split(',')
        r = int(r)
        yield u,b,r

def readJSON(path):
    data = []
    count = 0
    with gzip.open(path, 'rt') as f:
        for line in tqdm(f):
            json_obj = json.loads(line.strip())
            data.append(json_obj)
    df = pd.DataFrame(data)
    return df

def readJSON_slice(path, start=0, end=10000):
    data = []
    with gzip.open(path, 'rt') as f:
        for line in islice(f, start, end):
            try:
                data.append(json.loads(line.strip()))
            except json.JSONDecodeError as e:
                print(f"Error parsing line: {e}")
                continue
    df = pd.DataFrame(data)
    return df

# %%
random_seed = 42

# %%
categories = ['Children', 'Biography', 'Comics', 'Fantasy Paranormal', 'Mystery Thriller Crime', 'Poetry', 'Romance', 'Young Adult']
for category in categories:
    file_path = f"/content/drive/MyDrive/258/Goodreads {category} Books.json.gz"
    df = readJSON('/content/drive/MyDrive/258/Goodreads Children Books.json.gz')
    df = (df[df['language_code'] == 'eng']
          .assign(text_reviews_count=lambda x: pd.to_numeric(x['text_reviews_count']))
          .query('text_reviews_count >= 5')
          .sample(n=10000, random_state=random_seed)
          )
    columns_to_keep = ['book_id', 'work_id', 'title', 'title_without_series', 'series', 'average_rating', 'publication_year', 'num_pages', 'authors', 'publisher', 'description', 'ratings_count', 'text_reviews_count']
    sampled_df = sampled_df[columns_to_keep]
    sampled_df.to_csv(f"/content/drive/MyDrive/258/sampled/Goodreads {category} subset.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for category in categories:
#       3     file_path = f"/content/drive/MyDrive/258/Goodreads {category} Books.json.gz"
# ----> 4     df = readJSON('/content/drive/MyDrive/258/Goodreads Children Books.json.gz')
#       5     df = (df[df['language_code'] == 'eng']
#       6           .assign(text_reviews_count=lambda x: pd.to_numeric(x['text_reviews_count']))
#       7           .query('text_reviews_count >= 5')
#       8           .sample(n=10000, random_state=random_seed)
#       9           )
#      10     columns_to_keep = ['book_id', 'work_id', 'title', 'title_without_series', 'series', 'average_rating', 'publication_year', 'num_pages', 'authors', 'publisher', 'description', 'ratings_count', 'text_reviews_count']
#
# Cell In[2], line 12, in readJSON(path)
#      10 data = []
#      11 count = 0
# ---> 12 with gzip.open(path, 'rt') as f:
#      13     for line in tqdm(f):
#      14         json_obj = json.loads(line.strip())
#
# File ~/miniconda3/envs/work/lib/python3.10/gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59 elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60     binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# File ~/miniconda3/envs/work/lib/python3.10/gzip.py:174, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172     mode += 'b'
#     173 if fileobj is None:
# --> 174     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175 if filename is None:
#     176     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/258/Goodreads Children Books.json.gz'

# %%
interaction_df = pd.DataFrame(columns=['user_id', 'book_id', 'is_read', 'rating'])
review_df = pd.DataFrame(columns=['user_id', 'book_id', 'rating', 'review_text', 'n_votes'])

# %%
df = pd.read_csv(f"/Users/allenlu/Google Drive/My Drive/258/sampled/Goodreads Poetry subset.csv")

# %%
df.iloc[0]
# Out:
# book_id                                                          13508414
# work_id                                                          19060537
# title                                             The Delaware Detectives
# title_without_series                              The Delaware Detectives
# series                                                         ['853084']
# average_rating                                                       4.28
# publication_year                                                   2012.0
# num_pages                                                           150.0
# authors                            [{'author_id': '4998892', 'role': ''}]
# publisher                                       A Word Fitly Spoken Press
# description             What do the following have in common: a muntja...
# ratings_count                                                          12
# text_reviews_count                                                      6
# Name: 0, dtype: object

# %%
import pandas as pd
import gc
from pathlib import Path
import logging
from typing import Set, List, Dict
from dataclasses import dataclass
import gzip
import json
from concurrent.futures import ThreadPoolExecutor
import numpy as np

@dataclass
class ProcessingConfig:
    base_path: Path
    batch_size: int = 10000
    flush_threshold: int = 500000
    categories: List[str] = None

class GoodreadsProcessor:
    def __init__(self, config: ProcessingConfig):
        self.config = config
        self.setup_logging()
        
    def setup_logging(self):
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        self.logger = logging.getLogger(__name__)
    
    def read_json_slice(self, filepath: str, start: int, end: int) -> pd.DataFrame:
        records = []
        try:
            with gzip.open(filepath, 'rt', encoding='utf-8') as f:
                # Skip to start position
                for _ in range(start):
                    next(f, None)
                
                # Read specified chunk
                for _ in range(end - start):
                    line = next(f, None)
                    if line is None:
                        break
                    records.append(json.loads(line))
                    
        except Exception as e:
            self.logger.error(f"Error reading JSON slice: {e}")
            return pd.DataFrame()
            
        return pd.DataFrame.from_records(records) if records else pd.DataFrame()

    def process_slice(self, df_slice: pd.DataFrame, books: Set[int], columns: List[str]) -> List[Dict]:
        if df_slice.empty:
            return []
            
        # Convert book_ids efficiently using numpy
        df_slice['book_id'] = pd.to_numeric(df_slice['book_id'], errors='coerce').astype('Int64')
        
        # Vectorized filtering
        mask = df_slice['book_id'].isin(books)
        if 'is_read' in df_slice.columns:
            mask &= df_slice['is_read']
            
        filtered = df_slice[mask]
        return filtered[columns].to_dict('records')

    def process_category(self, category: str):
        # Initialize paths
        base = self.config.base_path
        interactions_path = base / f"Goodreads {category} Interactions.json.gz"
        reviews_path = base / f"Goodreads {category} Reviews.json.gz"
        # Read and cache book IDs
        books_df = pd.read_csv(base / 'sampled' / f"Goodreads {category} subset.csv")
        books = set(books_df['book_id'].astype(int))
        
        # Process interactions
        self._process_file(
            filepath=interactions_path,
            output_path=base / 'sampled' / f"Goodreads_{category}_Interactions_sampled.csv",
            columns=['user_id', 'book_id', 'is_read', 'rating'],
            books=books,
            file_type="interactions"
        )
        
        # Process reviews
        self._process_file(
            filepath=reviews_path,
            output_path=base / 'sampled' / f"Goodreads_{category}_Reviews_sampled.csv",
            columns=['user_id', 'book_id', 'rating', 'review_text', 'n_votes'],
            books=books,
            file_type="reviews"
        )

    def _process_file(self, filepath: Path, output_path: Path, columns: List[str], 
                     books: Set[int], file_type: str):
        # Initialize output file
        pd.DataFrame(columns=columns).to_csv(output_path, index=False)
        
        records = []
        count = 0
        batch_num = 0
        
        while True:
            start = batch_num * self.config.batch_size
            end = (batch_num + 1) * self.config.batch_size
            
            self.logger.info(f"Processing {file_type} batch {batch_num}, range: {start}-{end}")
            
            df_slice = self.read_json_slice(str(filepath), start, end)
            if df_slice.empty:
                break
                
            new_records = self.process_slice(df_slice, books, columns)
            records.extend(new_records)
            count += len(new_records)
            
            # Flush to disk if threshold reached
            if start % self.config.flush_threshold == 0 and start > 0 and records:
                self._flush_records(records, output_path)
                records = []
                gc.collect()
            
            batch_num += 1
        
        # Final flush
        if records:
            self._flush_records(records, output_path)
        
        self.logger.info(f"Completed processing {file_type}. Total records: {count}")
        
    def _flush_records(self, records: List[Dict], output_path: Path):
        pd.DataFrame(records).to_csv(output_path, mode='a', header=False, index=False)

    def process_all(self):
        for category in self.config.categories:
            self.logger.info(f"Starting processing for category: {category}")
            self.process_category(category)
            self.logger.info(f"Completed processing for category: {category}")

# %%
config = ProcessingConfig(
        base_path=Path("/Volumes/Drive/allenlu/Google Drive/My Drive/258/"),
        categories=['Fantasy Paranormal'],
        batch_size=50000,
        flush_threshold=500000
    )
    
processor = GoodreadsProcessor(config)
processor.process_all()
# Out:
# 2024-11-29 02:05:36,794 - INFO - Starting processing for category: Fantasy Paranormal
# 2024-11-29 02:05:36,869 - INFO - Processing interactions batch 0, range: 0-50000
# 2024-11-29 02:05:37,050 - INFO - Processing interactions batch 1, range: 50000-100000
# 2024-11-29 02:05:37,242 - INFO - Processing interactions batch 2, range: 100000-150000
# 2024-11-29 02:05:37,462 - INFO - Processing interactions batch 3, range: 150000-200000
# 2024-11-29 02:05:37,718 - INFO - Processing interactions batch 4, range: 200000-250000
# 2024-11-29 02:05:38,002 - INFO - Processing interactions batch 5, range: 250000-300000
# 2024-11-29 02:05:38,334 - INFO - Processing interactions batch 6, range: 300000-350000
# 2024-11-29 02:05:38,722 - INFO - Processing interactions batch 7, range: 350000-400000
# 2024-11-29 02:05:39,117 - INFO - Processing interactions batch 8, range: 400000-450000
# 2024-11-29 02:05:39,577 - INFO - Processing interactions batch 9, range: 450000-500000
# 2024-11-29 02:05:40,035 - INFO - Processing interactions batch 10, range: 500000-550000
# 2024-11-29 02:05:40,568 - INFO - Processing interactions batch 11, range: 550000-600000
# 2024-11-29 02:05:41,080 - INFO - Processing interactions batch 12, range: 600000-650000
# 2024-11-29 02:05:41,652 - INFO - Processing interactions batch 13, range: 650000-700000
# 2024-11-29 02:05:42,247 - INFO - Processing interactions batch 14, range: 700000-750000
# 2024-11-29 02:05:42,864 - INFO - Processing interactions batch 15, range: 750000-800000
# 2024-11-29 02:05:43,601 - INFO - Processing interactions batch 16, range: 800000-850000
# 2024-11-29 02:05:44,308 - INFO - Processing interactions batch 17, range: 850000-900000
# 2024-11-29 02:05:45,404 - INFO - Processing interactions batch 18, range: 900000-950000
# 2024-11-29 02:05:46,205 - INFO - Processing interactions batch 19, range: 950000-1000000
# 2024-11-29 02:05:47,105 - INFO - Processing interactions batch 20, range: 1000000-1050000
# 2024-11-29 02:05:48,031 - INFO - Processing interactions batch 21, range: 1050000-1100000
# 2024-11-29 02:05:48,999 - INFO - Processing interactions batch 22, range: 1100000-1150000
# 2024-11-29 02:05:49,910 - INFO - Processing interactions batch 23, range: 1150000-1200000
# 2024-11-29 02:05:50,881 - INFO - Processing interactions batch 24, range: 1200000-1250000
# 2024-11-29 02:05:51,829 - INFO - Processing interactions batch 25, range: 1250000-1300000
# 2024-11-29 02:05:52,795 - INFO - Processing interactions batch 26, range: 1300000-1350000
# 2024-11-29 02:05:53,854 - INFO - Processing interactions batch 27, range: 1350000-1400000
# 2024-11-29 02:05:55,181 - INFO - Processing interactions batch 28, range: 1400000-1450000
# 2024-11-29 02:05:56,361 - INFO - Processing interactions batch 29, range: 1450000-1500000
# 2024-11-29 02:05:57,700 - INFO - Processing interactions batch 30, range: 1500000-1550000
# 2024-11-29 02:05:59,006 - INFO - Processing interactions batch 31, range: 1550000-1600000
# 2024-11-29 02:06:00,194 - INFO - Processing interactions batch 32, range: 1600000-1650000
# 2024-11-29 02:06:01,458 - INFO - Processing interactions batch 33, range: 1650000-1700000
# 2024-11-29 02:06:02,745 - INFO - Processing interactions batch 34, range: 1700000-1750000
# 2024-11-29 02:06:04,072 - INFO - Processing interactions batch 35, range: 1750000-1800000
# 2024-11-29 02:06:05,378 - INFO - Processing interactions batch 36, range: 1800000-1850000
# 2024-11-29 02:06:06,707 - INFO - Processing interactions batch 37, range: 1850000-1900000
# 2024-11-29 02:06:08,155 - INFO - Processing interactions batch 38, range: 1900000-1950000
# 2024-11-29 02:06:09,570 - INFO - Processing interactions batch 39, range: 1950000-2000000
# 2024-11-29 02:06:11,000 - INFO - Processing interactions batch 40, range: 2000000-2050000
# 2024-11-29 02:06:12,488 - INFO - Processing interactions batch 41, range: 2050000-2100000
# 2024-11-29 02:06:13,986 - INFO - Processing interactions batch 42, range: 2100000-2150000
# 2024-11-29 02:06:15,507 - INFO - Processing interactions batch 43, range: 2150000-2200000
# 2024-11-29 02:06:17,054 - INFO - Processing interactions batch 44, range: 2200000-2250000
# 2024-11-29 02:06:18,660 - INFO - Processing interactions batch 45, range: 2250000-2300000
# 2024-11-29 02:06:20,279 - INFO - Processing interactions batch 46, range: 2300000-2350000
# 2024-11-29 02:06:21,953 - INFO - Processing interactions batch 47, range: 2350000-2400000
# 2024-11-29 02:06:23,650 - INFO - Processing interactions batch 48, range: 2400000-2450000
# 2024-11-29 02:06:25,379 - INFO - Processing interactions batch 49, range: 2450000-2500000
# 2024-11-29 02:06:27,164 - INFO - Processing interactions batch 50, range: 2500000-2550000
# 2024-11-29 02:06:29,018 - INFO - Processing interactions batch 51, range: 2550000-2600000
# 2024-11-29 02:06:30,823 - INFO - Processing interactions batch 52, range: 2600000-2650000
# 2024-11-29 02:06:33,561 - INFO - Processing interactions batch 53, range: 2650000-2700000
# 2024-11-29 02:06:35,954 - INFO - Processing interactions batch 54, range: 2700000-2750000
# 2024-11-29 02:06:38,229 - INFO - Processing interactions batch 55, range: 2750000-2800000
# 2024-11-29 02:06:40,218 - INFO - Processing interactions batch 56, range: 2800000-2850000
# 2024-11-29 02:06:42,200 - INFO - Processing interactions batch 57, range: 2850000-2900000
# 2024-11-29 02:06:44,324 - INFO - Processing interactions batch 58, range: 2900000-2950000
# 2024-11-29 02:06:46,549 - INFO - Processing interactions batch 59, range: 2950000-3000000
# 2024-11-29 02:06:49,101 - INFO - Processing interactions batch 60, range: 3000000-3050000
# 2024-11-29 02:06:51,495 - INFO - Processing interactions batch 61, range: 3050000-3100000
# 2024-11-29 02:06:53,722 - INFO - Processing interactions batch 62, range: 3100000-3150000
# 2024-11-29 02:06:55,959 - INFO - Processing interactions batch 63, range: 3150000-3200000
# 2024-11-29 02:06:58,619 - INFO - Processing interactions batch 64, range: 3200000-3250000
# 2024-11-29 02:07:01,001 - INFO - Processing interactions batch 65, range: 3250000-3300000
# 2024-11-29 02:07:03,316 - INFO - Processing interactions batch 66, range: 3300000-3350000
# 2024-11-29 02:07:05,771 - INFO - Processing interactions batch 67, range: 3350000-3400000
# 2024-11-29 02:07:08,306 - INFO - Processing interactions batch 68, range: 3400000-3450000
# 2024-11-29 02:07:10,751 - INFO - Processing interactions batch 69, range: 3450000-3500000
# 2024-11-29 02:07:13,608 - INFO - Processing interactions batch 70, range: 3500000-3550000
# 2024-11-29 02:07:16,222 - INFO - Processing interactions batch 71, range: 3550000-3600000
# 2024-11-29 02:07:18,913 - INFO - Processing interactions batch 72, range: 3600000-3650000
# 2024-11-29 02:07:22,351 - INFO - Processing interactions batch 73, range: 3650000-3700000
# 2024-11-29 02:07:25,404 - INFO - Processing interactions batch 74, range: 3700000-3750000
# 2024-11-29 02:07:28,456 - INFO - Processing interactions batch 75, range: 3750000-3800000
# 2024-11-29 02:07:31,320 - INFO - Processing interactions batch 76, range: 3800000-3850000
# 2024-11-29 02:07:34,171 - INFO - Processing interactions batch 77, range: 3850000-3900000
# 2024-11-29 02:07:37,077 - INFO - Processing interactions batch 78, range: 3900000-3950000
# 2024-11-29 02:07:40,080 - INFO - Processing interactions batch 79, range: 3950000-4000000
# 2024-11-29 02:07:43,073 - INFO - Processing interactions batch 80, range: 4000000-4050000
# 2024-11-29 02:07:46,088 - INFO - Processing interactions batch 81, range: 4050000-4100000
# 2024-11-29 02:07:48,989 - INFO - Processing interactions batch 82, range: 4100000-4150000
# 2024-11-29 02:07:51,984 - INFO - Processing interactions batch 83, range: 4150000-4200000
# 2024-11-29 02:07:54,959 - INFO - Processing interactions batch 84, range: 4200000-4250000
# 2024-11-29 02:07:57,858 - INFO - Processing interactions batch 85, range: 4250000-4300000
# 2024-11-29 02:08:00,832 - INFO - Processing interactions batch 86, range: 4300000-4350000
# 2024-11-29 02:08:03,808 - INFO - Processing interactions batch 87, range: 4350000-4400000
# 2024-11-29 02:08:07,179 - INFO - Processing interactions batch 88, range: 4400000-4450000
# 2024-11-29 02:08:10,273 - INFO - Processing interactions batch 89, range: 4450000-4500000
# 2024-11-29 02:08:13,415 - INFO - Processing interactions batch 90, range: 4500000-4550000
# 2024-11-29 02:08:16,770 - INFO - Processing interactions batch 91, range: 4550000-4600000
# 2024-11-29 02:08:20,048 - INFO - Processing interactions batch 92, range: 4600000-4650000
# 2024-11-29 02:08:23,320 - INFO - Processing interactions batch 93, range: 4650000-4700000
# 2024-11-29 02:08:26,732 - INFO - Processing interactions batch 94, range: 4700000-4750000
# 2024-11-29 02:08:30,293 - INFO - Processing interactions batch 95, range: 4750000-4800000
# 2024-11-29 02:08:33,603 - INFO - Processing interactions batch 96, range: 4800000-4850000
# 2024-11-29 02:08:37,004 - INFO - Processing interactions batch 97, range: 4850000-4900000
# 2024-11-29 02:08:40,432 - INFO - Processing interactions batch 98, range: 4900000-4950000
# 2024-11-29 02:08:44,012 - INFO - Processing interactions batch 99, range: 4950000-5000000
# 2024-11-29 02:08:47,491 - INFO - Processing interactions batch 100, range: 5000000-5050000
# 2024-11-29 02:08:51,150 - INFO - Processing interactions batch 101, range: 5050000-5100000
# 2024-11-29 02:08:54,824 - INFO - Processing interactions batch 102, range: 5100000-5150000
# 2024-11-29 02:08:58,445 - INFO - Processing interactions batch 103, range: 5150000-5200000
# 2024-11-29 02:09:02,579 - INFO - Processing interactions batch 104, range: 5200000-5250000
# 2024-11-29 02:09:06,411 - INFO - Processing interactions batch 105, range: 5250000-5300000
# 2024-11-29 02:09:10,823 - INFO - Processing interactions batch 106, range: 5300000-5350000
# 2024-11-29 02:09:15,166 - INFO - Processing interactions batch 107, range: 5350000-5400000
# 2024-11-29 02:09:18,901 - INFO - Processing interactions batch 108, range: 5400000-5450000
# 2024-11-29 02:09:23,515 - INFO - Processing interactions batch 109, range: 5450000-5500000
# 2024-11-29 02:09:27,331 - INFO - Processing interactions batch 110, range: 5500000-5550000
# 2024-11-29 02:09:31,741 - INFO - Processing interactions batch 111, range: 5550000-5600000
# 2024-11-29 02:09:36,844 - INFO - Processing interactions batch 112, range: 5600000-5650000
# 2024-11-29 02:09:40,752 - INFO - Processing interactions batch 113, range: 5650000-5700000
# 2024-11-29 02:09:45,626 - INFO - Processing interactions batch 114, range: 5700000-5750000
# 2024-11-29 02:09:49,603 - INFO - Processing interactions batch 115, range: 5750000-5800000
# 2024-11-29 02:09:54,197 - INFO - Processing interactions batch 116, range: 5800000-5850000
# 2024-11-29 02:09:59,137 - INFO - Processing interactions batch 117, range: 5850000-5900000
# 2024-11-29 02:10:03,249 - INFO - Processing interactions batch 118, range: 5900000-5950000
# 2024-11-29 02:10:08,053 - INFO - Processing interactions batch 119, range: 5950000-6000000
# 2024-11-29 02:10:13,065 - INFO - Processing interactions batch 120, range: 6000000-6050000
# 2024-11-29 02:10:17,299 - INFO - Processing interactions batch 121, range: 6050000-6100000
# 2024-11-29 02:10:22,876 - INFO - Processing interactions batch 122, range: 6100000-6150000
# 2024-11-29 02:10:27,132 - INFO - Processing interactions batch 123, range: 6150000-6200000
# 2024-11-29 02:10:31,934 - INFO - Processing interactions batch 124, range: 6200000-6250000
# 2024-11-29 02:10:37,220 - INFO - Processing interactions batch 125, range: 6250000-6300000
# 2024-11-29 02:10:41,626 - INFO - Processing interactions batch 126, range: 6300000-6350000
# 2024-11-29 02:10:46,573 - INFO - Processing interactions batch 127, range: 6350000-6400000
# 2024-11-29 02:10:50,963 - INFO - Processing interactions batch 128, range: 6400000-6450000
# 2024-11-29 02:10:55,800 - INFO - Processing interactions batch 129, range: 6450000-6500000
# 2024-11-29 02:11:01,222 - INFO - Processing interactions batch 130, range: 6500000-6550000
# 2024-11-29 02:11:05,751 - INFO - Processing interactions batch 131, range: 6550000-6600000
# 2024-11-29 02:11:12,216 - INFO - Processing interactions batch 132, range: 6600000-6650000
# 2024-11-29 02:11:16,805 - INFO - Processing interactions batch 133, range: 6650000-6700000
# 2024-11-29 02:11:21,815 - INFO - Processing interactions batch 134, range: 6700000-6750000
# 2024-11-29 02:11:27,385 - INFO - Processing interactions batch 135, range: 6750000-6800000
# 2024-11-29 02:11:32,136 - INFO - Processing interactions batch 136, range: 6800000-6850000
# 2024-11-29 02:11:37,371 - INFO - Processing interactions batch 137, range: 6850000-6900000
# 2024-11-29 02:11:42,208 - INFO - Processing interactions batch 138, range: 6900000-6950000
# 2024-11-29 02:11:47,615 - INFO - Processing interactions batch 139, range: 6950000-7000000
# 2024-11-29 02:11:52,582 - INFO - Processing interactions batch 140, range: 7000000-7050000
# 2024-11-29 02:11:58,186 - INFO - Processing interactions batch 141, range: 7050000-7100000
# 2024-11-29 02:12:04,433 - INFO - Processing interactions batch 142, range: 7100000-7150000
# 2024-11-29 02:12:09,261 - INFO - Processing interactions batch 143, range: 7150000-7200000
# 2024-11-29 02:12:14,904 - INFO - Processing interactions batch 144, range: 7200000-7250000
# 2024-11-29 02:12:20,639 - INFO - Processing interactions batch 145, range: 7250000-7300000
# 2024-11-29 02:12:25,712 - INFO - Processing interactions batch 146, range: 7300000-7350000
# 2024-11-29 02:12:31,461 - INFO - Processing interactions batch 147, range: 7350000-7400000
# 2024-11-29 02:12:36,635 - INFO - Processing interactions batch 148, range: 7400000-7450000
# 2024-11-29 02:12:42,544 - INFO - Processing interactions batch 149, range: 7450000-7500000
# 2024-11-29 02:12:47,639 - INFO - Processing interactions batch 150, range: 7500000-7550000
# 2024-11-29 02:12:53,451 - INFO - Processing interactions batch 151, range: 7550000-7600000
# 2024-11-29 02:13:00,528 - INFO - Processing interactions batch 152, range: 7600000-7650000
# 2024-11-29 02:13:05,968 - INFO - Processing interactions batch 153, range: 7650000-7700000
# 2024-11-29 02:13:11,857 - INFO - Processing interactions batch 154, range: 7700000-7750000
# 2024-11-29 02:13:17,887 - INFO - Processing interactions batch 155, range: 7750000-7800000
# 2024-11-29 02:13:23,277 - INFO - Processing interactions batch 156, range: 7800000-7850000
# 2024-11-29 02:13:29,325 - INFO - Processing interactions batch 157, range: 7850000-7900000
# 2024-11-29 02:13:34,771 - INFO - Processing interactions batch 158, range: 7900000-7950000
# 2024-11-29 02:13:40,751 - INFO - Processing interactions batch 159, range: 7950000-8000000
# 2024-11-29 02:13:46,920 - INFO - Processing interactions batch 160, range: 8000000-8050000
# 2024-11-29 02:13:52,326 - INFO - Processing interactions batch 161, range: 8050000-8100000
# 2024-11-29 02:13:59,486 - INFO - Processing interactions batch 162, range: 8100000-8150000
# 2024-11-29 02:14:05,219 - INFO - Processing interactions batch 163, range: 8150000-8200000
# 2024-11-29 02:14:11,487 - INFO - Processing interactions batch 164, range: 8200000-8250000
# 2024-11-29 02:14:17,833 - INFO - Processing interactions batch 165, range: 8250000-8300000
# 2024-11-29 02:14:23,636 - INFO - Processing interactions batch 166, range: 8300000-8350000
# 2024-11-29 02:14:29,786 - INFO - Processing interactions batch 167, range: 8350000-8400000
# 2024-11-29 02:14:35,611 - INFO - Processing interactions batch 168, range: 8400000-8450000
# 2024-11-29 02:14:41,829 - INFO - Processing interactions batch 169, range: 8450000-8500000
# 2024-11-29 02:14:48,473 - INFO - Processing interactions batch 170, range: 8500000-8550000
# 2024-11-29 02:14:54,241 - INFO - Processing interactions batch 171, range: 8550000-8600000
# 2024-11-29 02:15:01,452 - INFO - Processing interactions batch 172, range: 8600000-8650000
# 2024-11-29 02:15:07,428 - INFO - Processing interactions batch 173, range: 8650000-8700000
# 2024-11-29 02:15:14,000 - INFO - Processing interactions batch 174, range: 8700000-8750000
# 2024-11-29 02:15:20,757 - INFO - Processing interactions batch 175, range: 8750000-8800000
# 2024-11-29 02:15:26,696 - INFO - Processing interactions batch 176, range: 8800000-8850000
# 2024-11-29 02:15:33,291 - INFO - Processing interactions batch 177, range: 8850000-8900000
# 2024-11-29 02:15:39,584 - INFO - Processing interactions batch 178, range: 8900000-8950000
# 2024-11-29 02:15:46,419 - INFO - Processing interactions batch 179, range: 8950000-9000000
# 2024-11-29 02:15:54,543 - INFO - Processing interactions batch 180, range: 9000000-9050000
# 2024-11-29 02:16:01,020 - INFO - Processing interactions batch 181, range: 9050000-9100000
# 2024-11-29 02:16:08,303 - INFO - Processing interactions batch 182, range: 9100000-9150000
# 2024-11-29 02:16:15,076 - INFO - Processing interactions batch 183, range: 9150000-9200000
# 2024-11-29 02:16:22,174 - INFO - Processing interactions batch 184, range: 9200000-9250000
# 2024-11-29 02:16:29,312 - INFO - Processing interactions batch 185, range: 9250000-9300000
# 2024-11-29 02:16:35,754 - INFO - Processing interactions batch 186, range: 9300000-9350000
# 2024-11-29 02:16:42,890 - INFO - Processing interactions batch 187, range: 9350000-9400000
# 2024-11-29 02:16:49,309 - INFO - Processing interactions batch 188, range: 9400000-9450000
# 2024-11-29 02:16:57,090 - INFO - Processing interactions batch 189, range: 9450000-9500000
# 2024-11-29 02:17:04,717 - INFO - Processing interactions batch 190, range: 9500000-9550000
# 2024-11-29 02:17:11,496 - INFO - Processing interactions batch 191, range: 9550000-9600000
# 2024-11-29 02:17:19,018 - INFO - Processing interactions batch 192, range: 9600000-9650000
# 2024-11-29 02:17:25,885 - INFO - Processing interactions batch 193, range: 9650000-9700000
# 2024-11-29 02:17:33,015 - INFO - Processing interactions batch 194, range: 9700000-9750000
# 2024-11-29 02:17:39,624 - INFO - Processing interactions batch 195, range: 9750000-9800000
# 2024-11-29 02:17:46,838 - INFO - Processing interactions batch 196, range: 9800000-9850000
# 2024-11-29 02:17:54,294 - INFO - Processing interactions batch 197, range: 9850000-9900000
# 2024-11-29 02:18:00,961 - INFO - Processing interactions batch 198, range: 9900000-9950000
# 2024-11-29 02:18:08,311 - INFO - Processing interactions batch 199, range: 9950000-10000000
# 2024-11-29 02:18:15,705 - INFO - Processing interactions batch 200, range: 10000000-10050000
# 2024-11-29 02:18:23,329 - INFO - Processing interactions batch 201, range: 10050000-10100000
# 2024-11-29 02:18:31,022 - INFO - Processing interactions batch 202, range: 10100000-10150000
# 2024-11-29 02:18:37,888 - INFO - Processing interactions batch 203, range: 10150000-10200000
# 2024-11-29 02:18:45,555 - INFO - Processing interactions batch 204, range: 10200000-10250000
# 2024-11-29 02:18:52,561 - INFO - Processing interactions batch 205, range: 10250000-10300000
# 2024-11-29 02:19:00,293 - INFO - Processing interactions batch 206, range: 10300000-10350000
# 2024-11-29 02:19:08,085 - INFO - Processing interactions batch 207, range: 10350000-10400000
# 2024-11-29 02:19:15,067 - INFO - Processing interactions batch 208, range: 10400000-10450000
# 2024-11-29 02:19:22,771 - INFO - Processing interactions batch 209, range: 10450000-10500000
# 2024-11-29 02:19:29,764 - INFO - Processing interactions batch 210, range: 10500000-10550000
# 2024-11-29 02:19:37,481 - INFO - Processing interactions batch 211, range: 10550000-10600000
# 2024-11-29 02:19:45,204 - INFO - Processing interactions batch 212, range: 10600000-10650000
# 2024-11-29 02:19:52,489 - INFO - Processing interactions batch 213, range: 10650000-10700000
# 2024-11-29 02:20:00,159 - INFO - Processing interactions batch 214, range: 10700000-10750000
# 2024-11-29 02:20:07,527 - INFO - Processing interactions batch 215, range: 10750000-10800000
# 2024-11-29 02:20:15,261 - INFO - Processing interactions batch 216, range: 10800000-10850000
# 2024-11-29 02:20:23,205 - INFO - Processing interactions batch 217, range: 10850000-10900000
# 2024-11-29 02:20:30,398 - INFO - Processing interactions batch 218, range: 10900000-10950000
# 2024-11-29 02:20:38,201 - INFO - Processing interactions batch 219, range: 10950000-11000000
# 2024-11-29 02:20:45,579 - INFO - Processing interactions batch 220, range: 11000000-11050000
# 2024-11-29 02:20:53,477 - INFO - Processing interactions batch 221, range: 11050000-11100000
# 2024-11-29 02:21:01,556 - INFO - Processing interactions batch 222, range: 11100000-11150000
# 2024-11-29 02:21:08,895 - INFO - Processing interactions batch 223, range: 11150000-11200000
# 2024-11-29 02:21:16,921 - INFO - Processing interactions batch 224, range: 11200000-11250000
# 2024-11-29 02:21:24,544 - INFO - Processing interactions batch 225, range: 11250000-11300000
# 2024-11-29 02:21:32,723 - INFO - Processing interactions batch 226, range: 11300000-11350000
# 2024-11-29 02:21:40,847 - INFO - Processing interactions batch 227, range: 11350000-11400000
# 2024-11-29 02:21:48,563 - INFO - Processing interactions batch 228, range: 11400000-11450000
# 2024-11-29 02:21:56,749 - INFO - Processing interactions batch 229, range: 11450000-11500000
# 2024-11-29 02:22:04,489 - INFO - Processing interactions batch 230, range: 11500000-11550000
# 2024-11-29 02:22:12,820 - INFO - Processing interactions batch 231, range: 11550000-11600000
# 2024-11-29 02:22:21,450 - INFO - Processing interactions batch 232, range: 11600000-11650000
# 2024-11-29 02:22:29,332 - INFO - Processing interactions batch 233, range: 11650000-11700000
# 2024-11-29 02:22:37,575 - INFO - Processing interactions batch 234, range: 11700000-11750000
# 2024-11-29 02:22:45,602 - INFO - Processing interactions batch 235, range: 11750000-11800000
# 2024-11-29 02:22:54,061 - INFO - Processing interactions batch 236, range: 11800000-11850000
# 2024-11-29 02:23:02,735 - INFO - Processing interactions batch 237, range: 11850000-11900000
# 2024-11-29 02:23:10,701 - INFO - Processing interactions batch 238, range: 11900000-11950000
# 2024-11-29 02:23:19,169 - INFO - Processing interactions batch 239, range: 11950000-12000000
# 2024-11-29 02:23:28,002 - INFO - Processing interactions batch 240, range: 12000000-12050000
# 2024-11-29 02:23:36,069 - INFO - Processing interactions batch 241, range: 12050000-12100000
# 2024-11-29 02:23:44,819 - INFO - Processing interactions batch 242, range: 12100000-12150000
# 2024-11-29 02:23:52,979 - INFO - Processing interactions batch 243, range: 12150000-12200000
# 2024-11-29 02:24:01,671 - INFO - Processing interactions batch 244, range: 12200000-12250000
# 2024-11-29 02:24:10,500 - INFO - Processing interactions batch 245, range: 12250000-12300000
# 2024-11-29 02:24:18,616 - INFO - Processing interactions batch 246, range: 12300000-12350000
# 2024-11-29 02:24:27,469 - INFO - Processing interactions batch 247, range: 12350000-12400000
# 2024-11-29 02:24:35,778 - INFO - Processing interactions batch 248, range: 12400000-12450000
# 2024-11-29 02:24:44,464 - INFO - Processing interactions batch 249, range: 12450000-12500000
# 2024-11-29 02:24:53,481 - INFO - Processing interactions batch 250, range: 12500000-12550000
# 2024-11-29 02:25:01,815 - INFO - Processing interactions batch 251, range: 12550000-12600000
# 2024-11-29 02:25:10,685 - INFO - Processing interactions batch 252, range: 12600000-12650000
# 2024-11-29 02:25:19,082 - INFO - Processing interactions batch 253, range: 12650000-12700000
# 2024-11-29 02:25:27,961 - INFO - Processing interactions batch 254, range: 12700000-12750000
# 2024-11-29 02:25:36,767 - INFO - Processing interactions batch 255, range: 12750000-12800000
# 2024-11-29 02:25:45,293 - INFO - Processing interactions batch 256, range: 12800000-12850000
# 2024-11-29 02:25:54,547 - INFO - Processing interactions batch 257, range: 12850000-12900000
# 2024-11-29 02:26:03,807 - INFO - Processing interactions batch 258, range: 12900000-12950000
# 2024-11-29 02:26:12,385 - INFO - Processing interactions batch 259, range: 12950000-13000000
# 2024-11-29 02:26:21,668 - INFO - Processing interactions batch 260, range: 13000000-13050000
# 2024-11-29 02:26:30,482 - INFO - Processing interactions batch 261, range: 13050000-13100000
# 2024-11-29 02:26:39,685 - INFO - Processing interactions batch 262, range: 13100000-13150000
# 2024-11-29 02:26:48,955 - INFO - Processing interactions batch 263, range: 13150000-13200000
# 2024-11-29 02:26:57,662 - INFO - Processing interactions batch 264, range: 13200000-13250000
# 2024-11-29 02:27:06,918 - INFO - Processing interactions batch 265, range: 13250000-13300000
# 2024-11-29 02:27:15,781 - INFO - Processing interactions batch 266, range: 13300000-13350000
# 2024-11-29 02:27:25,417 - INFO - Processing interactions batch 267, range: 13350000-13400000
# 2024-11-29 02:27:35,043 - INFO - Processing interactions batch 268, range: 13400000-13450000
# 2024-11-29 02:27:44,197 - INFO - Processing interactions batch 269, range: 13450000-13500000
# 2024-11-29 02:27:53,825 - INFO - Processing interactions batch 270, range: 13500000-13550000
# 2024-11-29 02:28:02,977 - INFO - Processing interactions batch 271, range: 13550000-13600000
# 2024-11-29 02:28:12,661 - INFO - Processing interactions batch 272, range: 13600000-13650000
# 2024-11-29 02:28:22,431 - INFO - Processing interactions batch 273, range: 13650000-13700000
# 2024-11-29 02:28:31,496 - INFO - Processing interactions batch 274, range: 13700000-13750000
# 2024-11-29 02:28:41,227 - INFO - Processing interactions batch 275, range: 13750000-13800000
# 2024-11-29 02:28:50,419 - INFO - Processing interactions batch 276, range: 13800000-13850000
# 2024-11-29 02:28:59,980 - INFO - Processing interactions batch 277, range: 13850000-13900000
# 2024-11-29 02:29:09,841 - INFO - Processing interactions batch 278, range: 13900000-13950000
# 2024-11-29 02:29:19,078 - INFO - Processing interactions batch 279, range: 13950000-14000000
# 2024-11-29 02:29:29,090 - INFO - Processing interactions batch 280, range: 14000000-14050000
# 2024-11-29 02:29:39,056 - INFO - Processing interactions batch 281, range: 14050000-14100000
# 2024-11-29 02:29:48,487 - INFO - Processing interactions batch 282, range: 14100000-14150000
# 2024-11-29 02:29:58,307 - INFO - Processing interactions batch 283, range: 14150000-14200000
# 2024-11-29 02:30:07,820 - INFO - Processing interactions batch 284, range: 14200000-14250000
# 2024-11-29 02:30:17,675 - INFO - Processing interactions batch 285, range: 14250000-14300000
# 2024-11-29 02:30:27,157 - INFO - Processing interactions batch 286, range: 14300000-14350000
# 2024-11-29 02:30:37,209 - INFO - Processing interactions batch 287, range: 14350000-14400000
# 2024-11-29 02:30:47,468 - INFO - Processing interactions batch 288, range: 14400000-14450000
# 2024-11-29 02:30:57,032 - INFO - Processing interactions batch 289, range: 14450000-14500000
# 2024-11-29 02:31:07,232 - INFO - Processing interactions batch 290, range: 14500000-14550000
# 2024-11-29 02:31:16,793 - INFO - Processing interactions batch 291, range: 14550000-14600000
# 2024-11-29 02:31:26,860 - INFO - Processing interactions batch 292, range: 14600000-14650000
# 2024-11-29 02:31:37,124 - INFO - Processing interactions batch 293, range: 14650000-14700000
# 2024-11-29 02:31:46,944 - INFO - Processing interactions batch 294, range: 14700000-14750000
# 2024-11-29 02:31:57,258 - INFO - Processing interactions batch 295, range: 14750000-14800000
# 2024-11-29 02:32:07,855 - INFO - Processing interactions batch 296, range: 14800000-14850000
# 2024-11-29 02:32:17,548 - INFO - Processing interactions batch 297, range: 14850000-14900000
# 2024-11-29 02:32:28,053 - INFO - Processing interactions batch 298, range: 14900000-14950000
# 2024-11-29 02:32:37,928 - INFO - Processing interactions batch 299, range: 14950000-15000000
# 2024-11-29 02:32:48,440 - INFO - Processing interactions batch 300, range: 15000000-15050000
# 2024-11-29 02:32:58,322 - INFO - Processing interactions batch 301, range: 15050000-15100000
# 2024-11-29 02:33:08,998 - INFO - Processing interactions batch 302, range: 15100000-15150000
# 2024-11-29 02:33:19,665 - INFO - Processing interactions batch 303, range: 15150000-15200000
# 2024-11-29 02:33:29,679 - INFO - Processing interactions batch 304, range: 15200000-15250000
# 2024-11-29 02:33:40,252 - INFO - Processing interactions batch 305, range: 15250000-15300000
# 2024-11-29 02:33:50,577 - INFO - Processing interactions batch 306, range: 15300000-15350000
# 2024-11-29 02:34:01,269 - INFO - Processing interactions batch 307, range: 15350000-15400000
# 2024-11-29 02:34:11,978 - INFO - Processing interactions batch 308, range: 15400000-15450000
# 2024-11-29 02:34:22,308 - INFO - Processing interactions batch 309, range: 15450000-15500000
# 2024-11-29 02:34:33,113 - INFO - Processing interactions batch 310, range: 15500000-15550000
# 2024-11-29 02:34:44,233 - INFO - Processing interactions batch 311, range: 15550000-15600000
# 2024-11-29 02:34:54,860 - INFO - Processing interactions batch 312, range: 15600000-15650000
# 2024-11-29 02:35:05,727 - INFO - Processing interactions batch 313, range: 15650000-15700000
# 2024-11-29 02:35:16,080 - INFO - Processing interactions batch 314, range: 15700000-15750000
# 2024-11-29 02:35:27,054 - INFO - Processing interactions batch 315, range: 15750000-15800000
# 2024-11-29 02:35:37,971 - INFO - Processing interactions batch 316, range: 15800000-15850000
# 2024-11-29 02:35:48,382 - INFO - Processing interactions batch 317, range: 15850000-15900000
# 2024-11-29 02:35:59,460 - INFO - Processing interactions batch 318, range: 15900000-15950000
# 2024-11-29 02:36:10,104 - INFO - Processing interactions batch 319, range: 15950000-16000000
# 2024-11-29 02:36:21,401 - INFO - Processing interactions batch 320, range: 16000000-16050000
# 2024-11-29 02:36:31,975 - INFO - Processing interactions batch 321, range: 16050000-16100000
# 2024-11-29 02:36:43,326 - INFO - Processing interactions batch 322, range: 16100000-16150000
# 2024-11-29 02:36:54,782 - INFO - Processing interactions batch 323, range: 16150000-16200000
# 2024-11-29 02:37:05,561 - INFO - Processing interactions batch 324, range: 16200000-16250000
# 2024-11-29 02:37:16,844 - INFO - Processing interactions batch 325, range: 16250000-16300000
# 2024-11-29 02:37:27,711 - INFO - Processing interactions batch 326, range: 16300000-16350000
# 2024-11-29 02:37:39,174 - INFO - Processing interactions batch 327, range: 16350000-16400000
# 2024-11-29 02:37:50,569 - INFO - Processing interactions batch 328, range: 16400000-16450000
# 2024-11-29 02:38:01,336 - INFO - Processing interactions batch 329, range: 16450000-16500000
# 2024-11-29 02:38:12,678 - INFO - Processing interactions batch 330, range: 16500000-16550000
# 2024-11-29 02:38:23,798 - INFO - Processing interactions batch 331, range: 16550000-16600000
# 2024-11-29 02:38:35,215 - INFO - Processing interactions batch 332, range: 16600000-16650000
# 2024-11-29 02:38:47,014 - INFO - Processing interactions batch 333, range: 16650000-16700000
# 2024-11-29 02:38:57,900 - INFO - Processing interactions batch 334, range: 16700000-16750000
# 2024-11-29 02:39:09,282 - INFO - Processing interactions batch 335, range: 16750000-16800000
# 2024-11-29 02:39:20,329 - INFO - Processing interactions batch 336, range: 16800000-16850000
# 2024-11-29 02:39:31,890 - INFO - Processing interactions batch 337, range: 16850000-16900000
# 2024-11-29 02:39:43,546 - INFO - Processing interactions batch 338, range: 16900000-16950000
# 2024-11-29 02:39:54,582 - INFO - Processing interactions batch 339, range: 16950000-17000000
# 2024-11-29 02:40:06,276 - INFO - Processing interactions batch 340, range: 17000000-17050000
# 2024-11-29 02:40:17,684 - INFO - Processing interactions batch 341, range: 17050000-17100000
# 2024-11-29 02:40:29,642 - INFO - Processing interactions batch 342, range: 17100000-17150000
# 2024-11-29 02:40:41,638 - INFO - Processing interactions batch 343, range: 17150000-17200000
# 2024-11-29 02:40:52,809 - INFO - Processing interactions batch 344, range: 17200000-17250000
# 2024-11-29 02:41:04,695 - INFO - Processing interactions batch 345, range: 17250000-17300000
# 2024-11-29 02:41:16,839 - INFO - Processing interactions batch 346, range: 17300000-17350000
# 2024-11-29 02:41:28,405 - INFO - Processing interactions batch 347, range: 17350000-17400000
# 2024-11-29 02:41:40,613 - INFO - Processing interactions batch 348, range: 17400000-17450000
# 2024-11-29 02:41:52,284 - INFO - Processing interactions batch 349, range: 17450000-17500000
# 2024-11-29 02:42:04,588 - INFO - Processing interactions batch 350, range: 17500000-17550000
# 2024-11-29 02:42:16,784 - INFO - Processing interactions batch 351, range: 17550000-17600000
# 2024-11-29 02:42:28,494 - INFO - Processing interactions batch 352, range: 17600000-17650000
# 2024-11-29 02:42:40,786 - INFO - Processing interactions batch 353, range: 17650000-17700000
# 2024-11-29 02:42:52,305 - INFO - Processing interactions batch 354, range: 17700000-17750000
# 2024-11-29 02:43:04,587 - INFO - Processing interactions batch 355, range: 17750000-17800000
# 2024-11-29 02:43:16,305 - INFO - Processing interactions batch 356, range: 17800000-17850000
# 2024-11-29 02:43:28,789 - INFO - Processing interactions batch 357, range: 17850000-17900000
# 2024-11-29 02:43:41,304 - INFO - Processing interactions batch 358, range: 17900000-17950000
# 2024-11-29 02:43:53,214 - INFO - Processing interactions batch 359, range: 17950000-18000000
# 2024-11-29 02:44:05,666 - INFO - Processing interactions batch 360, range: 18000000-18050000
# 2024-11-29 02:44:18,203 - INFO - Processing interactions batch 361, range: 18050000-18100000
# 2024-11-29 02:44:30,540 - INFO - Processing interactions batch 362, range: 18100000-18150000
# 2024-11-29 02:44:43,016 - INFO - Processing interactions batch 363, range: 18150000-18200000
# 2024-11-29 02:44:54,823 - INFO - Processing interactions batch 364, range: 18200000-18250000
# 2024-11-29 02:45:07,290 - INFO - Processing interactions batch 365, range: 18250000-18300000
# 2024-11-29 02:45:19,708 - INFO - Processing interactions batch 366, range: 18300000-18350000
# 2024-11-29 02:45:31,598 - INFO - Processing interactions batch 367, range: 18350000-18400000
# 2024-11-29 02:45:44,107 - INFO - Processing interactions batch 368, range: 18400000-18450000
# 2024-11-29 02:45:56,116 - INFO - Processing interactions batch 369, range: 18450000-18500000
# 2024-11-29 02:46:08,725 - INFO - Processing interactions batch 370, range: 18500000-18550000
# 2024-11-29 02:46:21,555 - INFO - Processing interactions batch 371, range: 18550000-18600000
# 2024-11-29 02:46:33,669 - INFO - Processing interactions batch 372, range: 18600000-18650000
# 2024-11-29 02:46:46,601 - INFO - Processing interactions batch 373, range: 18650000-18700000
# 2024-11-29 02:46:58,661 - INFO - Processing interactions batch 374, range: 18700000-18750000
# 2024-11-29 02:47:11,701 - INFO - Processing interactions batch 375, range: 18750000-18800000
# 2024-11-29 02:47:24,884 - INFO - Processing interactions batch 376, range: 18800000-18850000
# 2024-11-29 02:47:37,249 - INFO - Processing interactions batch 377, range: 18850000-18900000
# 2024-11-29 02:47:50,468 - INFO - Processing interactions batch 378, range: 18900000-18950000
# 2024-11-29 02:48:02,706 - INFO - Processing interactions batch 379, range: 18950000-19000000
# 2024-11-29 02:48:15,866 - INFO - Processing interactions batch 380, range: 19000000-19050000
# 2024-11-29 02:48:29,155 - INFO - Processing interactions batch 381, range: 19050000-19100000
# 2024-11-29 02:48:42,051 - INFO - Processing interactions batch 382, range: 19100000-19150000
# 2024-11-29 02:48:54,988 - INFO - Processing interactions batch 383, range: 19150000-19200000
# 2024-11-29 02:49:07,447 - INFO - Processing interactions batch 384, range: 19200000-19250000
# 2024-11-29 02:49:20,573 - INFO - Processing interactions batch 385, range: 19250000-19300000
# 2024-11-29 02:49:33,672 - INFO - Processing interactions batch 386, range: 19300000-19350000
# 2024-11-29 02:49:46,502 - INFO - Processing interactions batch 387, range: 19350000-19400000
# 2024-11-29 02:49:59,763 - INFO - Processing interactions batch 388, range: 19400000-19450000
# 2024-11-29 02:50:12,561 - INFO - Processing interactions batch 389, range: 19450000-19500000
# 2024-11-29 02:50:25,710 - INFO - Processing interactions batch 390, range: 19500000-19550000
# 2024-11-29 02:50:38,363 - INFO - Processing interactions batch 391, range: 19550000-19600000
# 2024-11-29 02:50:51,578 - INFO - Processing interactions batch 392, range: 19600000-19650000
# 2024-11-29 02:51:04,939 - INFO - Processing interactions batch 393, range: 19650000-19700000
# 2024-11-29 02:51:17,660 - INFO - Processing interactions batch 394, range: 19700000-19750000
# 2024-11-29 02:51:31,021 - INFO - Processing interactions batch 395, range: 19750000-19800000
# 2024-11-29 02:51:44,579 - INFO - Processing interactions batch 396, range: 19800000-19850000
# 2024-11-29 02:51:57,675 - INFO - Processing interactions batch 397, range: 19850000-19900000
# 2024-11-29 02:52:11,303 - INFO - Processing interactions batch 398, range: 19900000-19950000
# 2024-11-29 02:52:24,377 - INFO - Processing interactions batch 399, range: 19950000-20000000
# 2024-11-29 02:52:38,028 - INFO - Processing interactions batch 400, range: 20000000-20050000
# 2024-11-29 02:52:52,133 - INFO - Processing interactions batch 401, range: 20050000-20100000
# 2024-11-29 02:53:05,297 - INFO - Processing interactions batch 402, range: 20100000-20150000
# 2024-11-29 02:53:18,945 - INFO - Processing interactions batch 403, range: 20150000-20200000
# 2024-11-29 02:53:32,383 - INFO - Processing interactions batch 404, range: 20200000-20250000
# 2024-11-29 02:53:46,235 - INFO - Processing interactions batch 405, range: 20250000-20300000
# 2024-11-29 02:53:59,877 - INFO - Processing interactions batch 406, range: 20300000-20350000
# 2024-11-29 02:54:13,295 - INFO - Processing interactions batch 407, range: 20350000-20400000
# 2024-11-29 02:54:26,893 - INFO - Processing interactions batch 408, range: 20400000-20450000
# 2024-11-29 02:54:40,152 - INFO - Processing interactions batch 409, range: 20450000-20500000
# 2024-11-29 02:54:53,947 - INFO - Processing interactions batch 410, range: 20500000-20550000
# 2024-11-29 02:55:07,905 - INFO - Processing interactions batch 411, range: 20550000-20600000
# 2024-11-29 02:55:21,187 - INFO - Processing interactions batch 412, range: 20600000-20650000
# 2024-11-29 02:55:34,962 - INFO - Processing interactions batch 413, range: 20650000-20700000
# 2024-11-29 02:55:48,500 - INFO - Processing interactions batch 414, range: 20700000-20750000
# 2024-11-29 02:56:02,589 - INFO - Processing interactions batch 415, range: 20750000-20800000
# 2024-11-29 02:56:16,726 - INFO - Processing interactions batch 416, range: 20800000-20850000
# 2024-11-29 02:56:30,343 - INFO - Processing interactions batch 417, range: 20850000-20900000
# 2024-11-29 02:56:44,512 - INFO - Processing interactions batch 418, range: 20900000-20950000
# 2024-11-29 02:56:58,104 - INFO - Processing interactions batch 419, range: 20950000-21000000
# 2024-11-29 02:57:12,360 - INFO - Processing interactions batch 420, range: 21000000-21050000
# 2024-11-29 02:57:26,725 - INFO - Processing interactions batch 421, range: 21050000-21100000
# 2024-11-29 02:57:40,402 - INFO - Processing interactions batch 422, range: 21100000-21150000
# 2024-11-29 02:57:54,528 - INFO - Processing interactions batch 423, range: 21150000-21200000
# 2024-11-29 02:58:08,186 - INFO - Processing interactions batch 424, range: 21200000-21250000
# 2024-11-29 02:58:22,429 - INFO - Processing interactions batch 425, range: 21250000-21300000
# 2024-11-29 02:58:36,830 - INFO - Processing interactions batch 426, range: 21300000-21350000
# 2024-11-29 02:58:50,754 - INFO - Processing interactions batch 427, range: 21350000-21400000
# 2024-11-29 02:59:05,204 - INFO - Processing interactions batch 428, range: 21400000-21450000
# 2024-11-29 02:59:19,000 - INFO - Processing interactions batch 429, range: 21450000-21500000
# 2024-11-29 02:59:33,375 - INFO - Processing interactions batch 430, range: 21500000-21550000
# 2024-11-29 02:59:48,009 - INFO - Processing interactions batch 431, range: 21550000-21600000
# 2024-11-29 03:00:01,999 - INFO - Processing interactions batch 432, range: 21600000-21650000
# 2024-11-29 03:00:16,541 - INFO - Processing interactions batch 433, range: 21650000-21700000
# 2024-11-29 03:00:30,369 - INFO - Processing interactions batch 434, range: 21700000-21750000
# 2024-11-29 03:00:45,212 - INFO - Processing interactions batch 435, range: 21750000-21800000
# 2024-11-29 03:00:59,985 - INFO - Processing interactions batch 436, range: 21800000-21850000
# 2024-11-29 03:01:14,139 - INFO - Processing interactions batch 437, range: 21850000-21900000
# 2024-11-29 03:01:28,968 - INFO - Processing interactions batch 438, range: 21900000-21950000
# 2024-11-29 03:01:43,253 - INFO - Processing interactions batch 439, range: 21950000-22000000
# 2024-11-29 03:01:58,051 - INFO - Processing interactions batch 440, range: 22000000-22050000
# 2024-11-29 03:02:12,828 - INFO - Processing interactions batch 441, range: 22050000-22100000
# 2024-11-29 03:02:26,988 - INFO - Processing interactions batch 442, range: 22100000-22150000
# 2024-11-29 03:02:41,973 - INFO - Processing interactions batch 443, range: 22150000-22200000
# 2024-11-29 03:02:56,679 - INFO - Processing interactions batch 444, range: 22200000-22250000
# 2024-11-29 03:03:11,668 - INFO - Processing interactions batch 445, range: 22250000-22300000
# 2024-11-29 03:03:26,932 - INFO - Processing interactions batch 446, range: 22300000-22350000
# 2024-11-29 03:03:41,556 - INFO - Processing interactions batch 447, range: 22350000-22400000
# 2024-11-29 03:03:57,011 - INFO - Processing interactions batch 448, range: 22400000-22450000
# 2024-11-29 03:04:11,584 - INFO - Processing interactions batch 449, range: 22450000-22500000
# 2024-11-29 03:04:26,996 - INFO - Processing interactions batch 450, range: 22500000-22550000
# 2024-11-29 03:04:41,931 - INFO - Processing interactions batch 451, range: 22550000-22600000
# 2024-11-29 03:04:56,780 - INFO - Processing interactions batch 452, range: 22600000-22650000
# 2024-11-29 03:05:12,120 - INFO - Processing interactions batch 453, range: 22650000-22700000
# 2024-11-29 03:05:26,950 - INFO - Processing interactions batch 454, range: 22700000-22750000
# 2024-11-29 03:05:42,092 - INFO - Processing interactions batch 455, range: 22750000-22800000
# 2024-11-29 03:05:57,178 - INFO - Processing interactions batch 456, range: 22800000-22850000
# 2024-11-29 03:06:11,784 - INFO - Processing interactions batch 457, range: 22850000-22900000
# 2024-11-29 03:06:26,840 - INFO - Processing interactions batch 458, range: 22900000-22950000
# 2024-11-29 03:06:41,657 - INFO - Processing interactions batch 459, range: 22950000-23000000
# 2024-11-29 03:06:57,201 - INFO - Processing interactions batch 460, range: 23000000-23050000
# 2024-11-29 03:07:12,720 - INFO - Processing interactions batch 461, range: 23050000-23100000
# 2024-11-29 03:07:27,708 - INFO - Processing interactions batch 462, range: 23100000-23150000
# 2024-11-29 03:07:43,448 - INFO - Processing interactions batch 463, range: 23150000-23200000
# 2024-11-29 03:07:58,502 - INFO - Processing interactions batch 464, range: 23200000-23250000
# 2024-11-29 03:08:14,303 - INFO - Processing interactions batch 465, range: 23250000-23300000
# 2024-11-29 03:08:30,005 - INFO - Processing interactions batch 466, range: 23300000-23350000
# 2024-11-29 03:08:45,383 - INFO - Processing interactions batch 467, range: 23350000-23400000
# 2024-11-29 03:09:01,212 - INFO - Processing interactions batch 468, range: 23400000-23450000
# 2024-11-29 03:09:16,692 - INFO - Processing interactions batch 469, range: 23450000-23500000
# 2024-11-29 03:09:32,513 - INFO - Processing interactions batch 470, range: 23500000-23550000
# 2024-11-29 03:09:48,483 - INFO - Processing interactions batch 471, range: 23550000-23600000
# 2024-11-29 03:10:03,759 - INFO - Processing interactions batch 472, range: 23600000-23650000
# 2024-11-29 03:10:19,346 - INFO - Processing interactions batch 473, range: 23650000-23700000
# 2024-11-29 03:10:34,817 - INFO - Processing interactions batch 474, range: 23700000-23750000
# 2024-11-29 03:10:50,635 - INFO - Processing interactions batch 475, range: 23750000-23800000
# 2024-11-29 03:11:06,508 - INFO - Processing interactions batch 476, range: 23800000-23850000
# 2024-11-29 03:11:21,728 - INFO - Processing interactions batch 477, range: 23850000-23900000
# 2024-11-29 03:11:37,701 - INFO - Processing interactions batch 478, range: 23900000-23950000
# 2024-11-29 03:11:52,998 - INFO - Processing interactions batch 479, range: 23950000-24000000
# 2024-11-29 03:12:08,982 - INFO - Processing interactions batch 480, range: 24000000-24050000
# 2024-11-29 03:12:25,037 - INFO - Processing interactions batch 481, range: 24050000-24100000
# 2024-11-29 03:12:40,662 - INFO - Processing interactions batch 482, range: 24100000-24150000
# 2024-11-29 03:12:56,850 - INFO - Processing interactions batch 483, range: 24150000-24200000
# 2024-11-29 03:13:13,244 - INFO - Processing interactions batch 484, range: 24200000-24250000
# 2024-11-29 03:13:28,752 - INFO - Processing interactions batch 485, range: 24250000-24300000
# 2024-11-29 03:13:44,914 - INFO - Processing interactions batch 486, range: 24300000-24350000
# 2024-11-29 03:14:00,681 - INFO - Processing interactions batch 487, range: 24350000-24400000
# 2024-11-29 03:14:17,021 - INFO - Processing interactions batch 488, range: 24400000-24450000
# 2024-11-29 03:14:33,482 - INFO - Processing interactions batch 489, range: 24450000-24500000
# 2024-11-29 03:14:49,273 - INFO - Processing interactions batch 490, range: 24500000-24550000
# 2024-11-29 03:15:05,530 - INFO - Processing interactions batch 491, range: 24550000-24600000
# 2024-11-29 03:15:21,378 - INFO - Processing interactions batch 492, range: 24600000-24650000
# 2024-11-29 03:15:37,761 - INFO - Processing interactions batch 493, range: 24650000-24700000
# 2024-11-29 03:15:54,408 - INFO - Processing interactions batch 494, range: 24700000-24750000
# 2024-11-29 03:16:10,239 - INFO - Processing interactions batch 495, range: 24750000-24800000
# 2024-11-29 03:16:26,601 - INFO - Processing interactions batch 496, range: 24800000-24850000
# 2024-11-29 03:16:43,503 - INFO - Processing interactions batch 497, range: 24850000-24900000
# 2024-11-29 03:16:59,415 - INFO - Processing interactions batch 498, range: 24900000-24950000
# 2024-11-29 03:17:16,157 - INFO - Processing interactions batch 499, range: 24950000-25000000
# 2024-11-29 03:17:32,305 - INFO - Processing interactions batch 500, range: 25000000-25050000
# 2024-11-29 03:17:49,030 - INFO - Processing interactions batch 501, range: 25050000-25100000
# 2024-11-29 03:18:05,874 - INFO - Processing interactions batch 502, range: 25100000-25150000
# 2024-11-29 03:18:22,013 - INFO - Processing interactions batch 503, range: 25150000-25200000
# 2024-11-29 03:18:38,869 - INFO - Processing interactions batch 504, range: 25200000-25250000
# 2024-11-29 03:18:55,005 - INFO - Processing interactions batch 505, range: 25250000-25300000
# 2024-11-29 03:19:11,697 - INFO - Processing interactions batch 506, range: 25300000-25350000
# 2024-11-29 03:19:28,758 - INFO - Processing interactions batch 507, range: 25350000-25400000
# 2024-11-29 03:19:45,307 - INFO - Processing interactions batch 508, range: 25400000-25450000
# 2024-11-29 03:20:01,907 - INFO - Processing interactions batch 509, range: 25450000-25500000
# 2024-11-29 03:20:18,478 - INFO - Processing interactions batch 510, range: 25500000-25550000
# 2024-11-29 03:20:35,576 - INFO - Processing interactions batch 511, range: 25550000-25600000
# 2024-11-29 03:20:52,576 - INFO - Processing interactions batch 512, range: 25600000-25650000
# 2024-11-29 03:21:08,939 - INFO - Processing interactions batch 513, range: 25650000-25700000
# 2024-11-29 03:21:25,867 - INFO - Processing interactions batch 514, range: 25700000-25750000
# 2024-11-29 03:21:42,467 - INFO - Processing interactions batch 515, range: 25750000-25800000
# 2024-11-29 03:21:59,504 - INFO - Processing interactions batch 516, range: 25800000-25850000
# 2024-11-29 03:22:16,853 - INFO - Processing interactions batch 517, range: 25850000-25900000
# 2024-11-29 03:22:33,612 - INFO - Processing interactions batch 518, range: 25900000-25950000
# 2024-11-29 03:22:50,841 - INFO - Processing interactions batch 519, range: 25950000-26000000
# 2024-11-29 03:23:07,935 - INFO - Processing interactions batch 520, range: 26000000-26050000
# ...
# 2024-11-29 06:53:29,901 - INFO - Processing interactions batch 1005, range: 50250000-50300000
# 2024-11-29 06:54:06,924 - INFO - Processing interactions batch 1006, range: 50300000-50350000
# 2024-11-29 06:54:44,947 - INFO - Processing interactions batch 1007, range: 50350000-50400000
# 2024-11-29 06:55:21,973 - INFO - Processing interactions batch 1008, range: 50400000-50450000
# 2024-11-29 06:56:00,223 - INFO - Processing interactions batch 1009, range: 50450000-50500000
# 2024-11-29 06:56:37,365 - INFO - Processing interactions batch 1010, range: 50500000-50550000
# 2024-11-29 06:57:15,342 - INFO - Processing interactions batch 1011, range: 50550000-50600000
# 2024-11-29 06:57:53,112 - INFO - Processing interactions batch 1012, range: 50600000-50650000
# 2024-11-29 06:58:30,573 - INFO - Processing interactions batch 1013, range: 50650000-50700000
# 2024-11-29 06:59:08,436 - INFO - Processing interactions batch 1014, range: 50700000-50750000
# 2024-11-29 06:59:45,959 - INFO - Processing interactions batch 1015, range: 50750000-50800000
# 2024-11-29 07:00:23,623 - INFO - Processing interactions batch 1016, range: 50800000-50850000
# 2024-11-29 07:01:01,806 - INFO - Processing interactions batch 1017, range: 50850000-50900000
# 2024-11-29 07:01:39,329 - INFO - Processing interactions batch 1018, range: 50900000-50950000
# 2024-11-29 07:02:17,768 - INFO - Processing interactions batch 1019, range: 50950000-51000000
# 2024-11-29 07:02:56,366 - INFO - Processing interactions batch 1020, range: 51000000-51050000
# 2024-11-29 07:03:34,159 - INFO - Processing interactions batch 1021, range: 51050000-51100000
# 2024-11-29 07:04:13,442 - INFO - Processing interactions batch 1022, range: 51100000-51150000
# 2024-11-29 07:04:51,206 - INFO - Processing interactions batch 1023, range: 51150000-51200000
# 2024-11-29 07:05:29,358 - INFO - Processing interactions batch 1024, range: 51200000-51250000
# 2024-11-29 07:06:07,787 - INFO - Processing interactions batch 1025, range: 51250000-51300000
# 2024-11-29 07:06:45,565 - INFO - Processing interactions batch 1026, range: 51300000-51350000
# 2024-11-29 07:07:24,342 - INFO - Processing interactions batch 1027, range: 51350000-51400000
# 2024-11-29 07:08:02,215 - INFO - Processing interactions batch 1028, range: 51400000-51450000
# 2024-11-29 07:08:41,360 - INFO - Processing interactions batch 1029, range: 51450000-51500000
# 2024-11-29 07:09:20,196 - INFO - Processing interactions batch 1030, range: 51500000-51550000
# 2024-11-29 07:09:57,954 - INFO - Processing interactions batch 1031, range: 51550000-51600000
# 2024-11-29 07:10:36,476 - INFO - Processing interactions batch 1032, range: 51600000-51650000
# 2024-11-29 07:11:14,452 - INFO - Processing interactions batch 1033, range: 51650000-51700000
# 2024-11-29 07:11:52,628 - INFO - Processing interactions batch 1034, range: 51700000-51750000
# 2024-11-29 07:12:30,899 - INFO - Processing interactions batch 1035, range: 51750000-51800000
# 2024-11-29 07:13:08,709 - INFO - Processing interactions batch 1036, range: 51800000-51850000
# 2024-11-29 07:13:47,609 - INFO - Processing interactions batch 1037, range: 51850000-51900000
# 2024-11-29 07:14:26,362 - INFO - Processing interactions batch 1038, range: 51900000-51950000
# 2024-11-29 07:15:05,088 - INFO - Processing interactions batch 1039, range: 51950000-52000000
# 2024-11-29 07:15:44,577 - INFO - Processing interactions batch 1040, range: 52000000-52050000
# 2024-11-29 07:16:22,751 - INFO - Processing interactions batch 1041, range: 52050000-52100000
# 2024-11-29 07:17:01,505 - INFO - Processing interactions batch 1042, range: 52100000-52150000
# 2024-11-29 07:17:40,399 - INFO - Processing interactions batch 1043, range: 52150000-52200000
# 2024-11-29 07:18:19,751 - INFO - Processing interactions batch 1044, range: 52200000-52250000
# 2024-11-29 07:18:58,679 - INFO - Processing interactions batch 1045, range: 52250000-52300000
# 2024-11-29 07:19:37,435 - INFO - Processing interactions batch 1046, range: 52300000-52350000
# 2024-11-29 07:20:16,186 - INFO - Processing interactions batch 1047, range: 52350000-52400000
# 2024-11-29 07:20:54,386 - INFO - Processing interactions batch 1048, range: 52400000-52450000
# 2024-11-29 07:21:33,468 - INFO - Processing interactions batch 1049, range: 52450000-52500000
# 2024-11-29 07:22:12,045 - INFO - Processing interactions batch 1050, range: 52500000-52550000
# 2024-11-29 07:22:51,393 - INFO - Processing interactions batch 1051, range: 52550000-52600000
# 2024-11-29 07:23:30,804 - INFO - Processing interactions batch 1052, range: 52600000-52650000
# 2024-11-29 07:24:09,624 - INFO - Processing interactions batch 1053, range: 52650000-52700000
# 2024-11-29 07:24:48,367 - INFO - Processing interactions batch 1054, range: 52700000-52750000
# 2024-11-29 07:25:26,862 - INFO - Processing interactions batch 1055, range: 52750000-52800000
# 2024-11-29 07:26:05,891 - INFO - Processing interactions batch 1056, range: 52800000-52850000
# 2024-11-29 07:26:44,573 - INFO - Processing interactions batch 1057, range: 52850000-52900000
# 2024-11-29 07:27:24,307 - INFO - Processing interactions batch 1058, range: 52900000-52950000
# 2024-11-29 07:28:04,114 - INFO - Processing interactions batch 1059, range: 52950000-53000000
# 2024-11-29 07:28:44,953 - INFO - Processing interactions batch 1060, range: 53000000-53050000
# 2024-11-29 07:29:24,784 - INFO - Processing interactions batch 1061, range: 53050000-53100000
# 2024-11-29 07:30:04,629 - INFO - Processing interactions batch 1062, range: 53100000-53150000
# 2024-11-29 07:30:44,256 - INFO - Processing interactions batch 1063, range: 53150000-53200000
# 2024-11-29 07:31:22,968 - INFO - Processing interactions batch 1064, range: 53200000-53250000
# 2024-11-29 07:32:02,704 - INFO - Processing interactions batch 1065, range: 53250000-53300000
# 2024-11-29 07:32:42,675 - INFO - Processing interactions batch 1066, range: 53300000-53350000
# 2024-11-29 07:33:21,879 - INFO - Processing interactions batch 1067, range: 53350000-53400000
# 2024-11-29 07:34:01,655 - INFO - Processing interactions batch 1068, range: 53400000-53450000
# 2024-11-29 07:34:40,632 - INFO - Processing interactions batch 1069, range: 53450000-53500000
# 2024-11-29 07:35:20,460 - INFO - Processing interactions batch 1070, range: 53500000-53550000
# 2024-11-29 07:36:00,119 - INFO - Processing interactions batch 1071, range: 53550000-53600000
# 2024-11-29 07:36:40,155 - INFO - Processing interactions batch 1072, range: 53600000-53650000
# 2024-11-29 07:37:20,595 - INFO - Processing interactions batch 1073, range: 53650000-53700000
# 2024-11-29 07:38:00,509 - INFO - Processing interactions batch 1074, range: 53700000-53750000
# 2024-11-29 07:38:40,566 - INFO - Processing interactions batch 1075, range: 53750000-53800000
# 2024-11-29 07:39:20,310 - INFO - Processing interactions batch 1076, range: 53800000-53850000
# 2024-11-29 07:40:00,363 - INFO - Processing interactions batch 1077, range: 53850000-53900000
# 2024-11-29 07:40:40,771 - INFO - Processing interactions batch 1078, range: 53900000-53950000
# 2024-11-29 07:41:20,633 - INFO - Processing interactions batch 1079, range: 53950000-54000000
# 2024-11-29 07:42:01,110 - INFO - Processing interactions batch 1080, range: 54000000-54050000
# 2024-11-29 07:42:40,743 - INFO - Processing interactions batch 1081, range: 54050000-54100000
# 2024-11-29 07:43:21,581 - INFO - Processing interactions batch 1082, range: 54100000-54150000
# 2024-11-29 07:44:02,802 - INFO - Processing interactions batch 1083, range: 54150000-54200000
# 2024-11-29 07:44:42,219 - INFO - Processing interactions batch 1084, range: 54200000-54250000
# 2024-11-29 07:45:23,070 - INFO - Processing interactions batch 1085, range: 54250000-54300000
# 2024-11-29 07:46:03,023 - INFO - Processing interactions batch 1086, range: 54300000-54350000
# 2024-11-29 07:46:43,689 - INFO - Processing interactions batch 1087, range: 54350000-54400000
# 2024-11-29 07:47:23,560 - INFO - Processing interactions batch 1088, range: 54400000-54450000
# 2024-11-29 07:48:04,390 - INFO - Processing interactions batch 1089, range: 54450000-54500000
# 2024-11-29 07:48:46,068 - INFO - Processing interactions batch 1090, range: 54500000-54550000
# 2024-11-29 07:49:26,056 - INFO - Processing interactions batch 1091, range: 54550000-54600000
# 2024-11-29 07:50:07,313 - INFO - Processing interactions batch 1092, range: 54600000-54650000
# 2024-11-29 07:50:47,446 - INFO - Processing interactions batch 1093, range: 54650000-54700000
# 2024-11-29 07:51:28,423 - INFO - Processing interactions batch 1094, range: 54700000-54750000
# 2024-11-29 07:52:08,850 - INFO - Processing interactions batch 1095, range: 54750000-54800000
# 2024-11-29 07:52:49,950 - INFO - Processing interactions batch 1096, range: 54800000-54850000
# 2024-11-29 07:53:30,891 - INFO - Processing interactions batch 1097, range: 54850000-54900000
# 2024-11-29 07:54:11,652 - INFO - Processing interactions batch 1098, range: 54900000-54950000
# 2024-11-29 07:54:53,294 - INFO - Processing interactions batch 1099, range: 54950000-55000000
# 2024-11-29 07:55:33,885 - INFO - Processing interactions batch 1100, range: 55000000-55050000
# 2024-11-29 07:56:14,774 - INFO - Processing interactions batch 1101, range: 55050000-55100000
# 2024-11-29 07:56:55,844 - INFO - Processing interactions batch 1102, range: 55100000-55150000
# 2024-11-29 07:57:36,721 - INFO - Processing interactions batch 1103, range: 55150000-55200000
# 2024-11-29 07:58:18,095 - INFO - Processing interactions batch 1104, range: 55200000-55250000
# 2024-11-29 07:58:58,964 - INFO - Processing interactions batch 1105, range: 55250000-55300000
# 2024-11-29 07:59:40,035 - INFO - Processing interactions batch 1106, range: 55300000-55350000
# 2024-11-29 08:00:21,043 - INFO - Processing interactions batch 1107, range: 55350000-55400000
# 2024-11-29 08:01:02,333 - INFO - Processing interactions batch 1108, range: 55400000-55450000
# 2024-11-29 08:01:38,320 - INFO - Completed processing interactions. Total records: 1084340
# 2024-11-29 08:01:38,327 - INFO - Processing reviews batch 0, range: 0-50000
# 2024-11-29 08:01:46,348 - INFO - Processing reviews batch 1, range: 50000-100000
# 2024-11-29 08:01:47,307 - INFO - Processing reviews batch 2, range: 100000-150000
# 2024-11-29 08:01:48,896 - INFO - Processing reviews batch 3, range: 150000-200000
# 2024-11-29 08:01:50,303 - INFO - Processing reviews batch 4, range: 200000-250000
# 2024-11-29 08:01:52,161 - INFO - Processing reviews batch 5, range: 250000-300000
# 2024-11-29 08:01:54,701 - INFO - Processing reviews batch 6, range: 300000-350000
# 2024-11-29 08:01:56,375 - INFO - Processing reviews batch 7, range: 350000-400000
# 2024-11-29 08:01:58,669 - INFO - Processing reviews batch 8, range: 400000-450000
# 2024-11-29 08:02:01,569 - INFO - Processing reviews batch 9, range: 450000-500000
# 2024-11-29 08:02:04,627 - INFO - Processing reviews batch 10, range: 500000-550000
# 2024-11-29 08:02:07,986 - INFO - Processing reviews batch 11, range: 550000-600000
# 2024-11-29 08:02:14,802 - INFO - Processing reviews batch 12, range: 600000-650000
# 2024-11-29 08:02:17,877 - INFO - Processing reviews batch 13, range: 650000-700000
# 2024-11-29 08:02:21,592 - INFO - Processing reviews batch 14, range: 700000-750000
# 2024-11-29 08:02:25,400 - INFO - Processing reviews batch 15, range: 750000-800000
# 2024-11-29 08:02:29,395 - INFO - Processing reviews batch 16, range: 800000-850000
# 2024-11-29 08:02:33,605 - INFO - Processing reviews batch 17, range: 850000-900000
# 2024-11-29 08:02:38,224 - INFO - Processing reviews batch 18, range: 900000-950000
# 2024-11-29 08:02:42,636 - INFO - Processing reviews batch 19, range: 950000-1000000
# 2024-11-29 08:02:47,331 - INFO - Processing reviews batch 20, range: 1000000-1050000
# 2024-11-29 08:02:52,296 - INFO - Processing reviews batch 21, range: 1050000-1100000
# 2024-11-29 08:03:00,301 - INFO - Processing reviews batch 22, range: 1100000-1150000
# 2024-11-29 08:03:05,386 - INFO - Processing reviews batch 23, range: 1150000-1200000
# 2024-11-29 08:03:10,723 - INFO - Processing reviews batch 24, range: 1200000-1250000
# 2024-11-29 08:03:16,085 - INFO - Processing reviews batch 25, range: 1250000-1300000
# 2024-11-29 08:03:21,804 - INFO - Processing reviews batch 26, range: 1300000-1350000
# 2024-11-29 08:03:27,555 - INFO - Processing reviews batch 27, range: 1350000-1400000
# 2024-11-29 08:03:33,504 - INFO - Processing reviews batch 28, range: 1400000-1450000
# 2024-11-29 08:03:39,775 - INFO - Processing reviews batch 29, range: 1450000-1500000
# 2024-11-29 08:03:46,030 - INFO - Processing reviews batch 30, range: 1500000-1550000
# 2024-11-29 08:03:53,167 - INFO - Processing reviews batch 31, range: 1550000-1600000
# 2024-11-29 08:04:02,889 - INFO - Processing reviews batch 32, range: 1600000-1650000
# 2024-11-29 08:04:10,019 - INFO - Processing reviews batch 33, range: 1650000-1700000
# 2024-11-29 08:04:16,890 - INFO - Processing reviews batch 34, range: 1700000-1750000
# 2024-11-29 08:04:24,437 - INFO - Processing reviews batch 35, range: 1750000-1800000
# 2024-11-29 08:04:32,027 - INFO - Processing reviews batch 36, range: 1800000-1850000
# 2024-11-29 08:04:39,403 - INFO - Processing reviews batch 37, range: 1850000-1900000
# 2024-11-29 08:04:47,598 - INFO - Processing reviews batch 38, range: 1900000-1950000
# 2024-11-29 08:04:55,350 - INFO - Processing reviews batch 39, range: 1950000-2000000
# 2024-11-29 08:05:03,338 - INFO - Processing reviews batch 40, range: 2000000-2050000
# 2024-11-29 08:05:12,204 - INFO - Processing reviews batch 41, range: 2050000-2100000
# 2024-11-29 08:05:21,433 - INFO - Processing reviews batch 42, range: 2100000-2150000
# 2024-11-29 08:05:30,156 - INFO - Processing reviews batch 43, range: 2150000-2200000
# 2024-11-29 08:05:38,731 - INFO - Processing reviews batch 44, range: 2200000-2250000
# 2024-11-29 08:05:47,921 - INFO - Processing reviews batch 45, range: 2250000-2300000
# 2024-11-29 08:05:57,690 - INFO - Processing reviews batch 46, range: 2300000-2350000
# 2024-11-29 08:06:07,548 - INFO - Processing reviews batch 47, range: 2350000-2400000
# 2024-11-29 08:06:17,851 - INFO - Processing reviews batch 48, range: 2400000-2450000
# 2024-11-29 08:06:28,062 - INFO - Processing reviews batch 49, range: 2450000-2500000
# 2024-11-29 08:06:38,480 - INFO - Processing reviews batch 50, range: 2500000-2550000
# 2024-11-29 08:06:48,615 - INFO - Processing reviews batch 51, range: 2550000-2600000
# 2024-11-29 08:06:58,961 - INFO - Processing reviews batch 52, range: 2600000-2650000
# 2024-11-29 08:07:09,562 - INFO - Processing reviews batch 53, range: 2650000-2700000
# 2024-11-29 08:07:20,584 - INFO - Processing reviews batch 54, range: 2700000-2750000
# 2024-11-29 08:07:31,893 - INFO - Processing reviews batch 55, range: 2750000-2800000
# 2024-11-29 08:07:42,918 - INFO - Processing reviews batch 56, range: 2800000-2850000
# 2024-11-29 08:07:54,581 - INFO - Processing reviews batch 57, range: 2850000-2900000
# 2024-11-29 08:08:05,734 - INFO - Processing reviews batch 58, range: 2900000-2950000
# 2024-11-29 08:08:17,524 - INFO - Processing reviews batch 59, range: 2950000-3000000
# 2024-11-29 08:08:29,385 - INFO - Processing reviews batch 60, range: 3000000-3050000
# 2024-11-29 08:08:41,361 - INFO - Processing reviews batch 61, range: 3050000-3100000
# 2024-11-29 08:08:53,084 - INFO - Processing reviews batch 62, range: 3100000-3150000
# 2024-11-29 08:09:05,254 - INFO - Processing reviews batch 63, range: 3150000-3200000
# 2024-11-29 08:09:17,499 - INFO - Processing reviews batch 64, range: 3200000-3250000
# 2024-11-29 08:09:29,324 - INFO - Processing reviews batch 65, range: 3250000-3300000
# 2024-11-29 08:09:41,255 - INFO - Processing reviews batch 66, range: 3300000-3350000
# 2024-11-29 08:09:53,220 - INFO - Processing reviews batch 67, range: 3350000-3400000
# 2024-11-29 08:10:05,313 - INFO - Processing reviews batch 68, range: 3400000-3450000
# 2024-11-29 08:10:17,189 - INFO - Processing reviews batch 69, range: 3450000-3500000
# 2024-11-29 08:10:28,156 - INFO - Completed processing reviews. Total records: 129790
# 2024-11-29 08:10:28,163 - INFO - Completed processing for category: Fantasy Paranormal
